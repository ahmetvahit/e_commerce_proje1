# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("data.csv", encoding="latin1")

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# CustomerID     135080
# Description      1454
# InvoiceNo           0
# StockCode           0
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# Country             0
# dtype: int64

# %%
df["CustomerID"]=df.CustomerID.fillna(1)

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# Description    1454
# InvoiceNo         0
# StockCode         0
# Quantity          0
# InvoiceDate       0
# UnitPrice         0
# CustomerID        0
# Country           0
# dtype: int64

# %%
df2=df.dropna(how="any" )

# %%
df2.isnull().sum().sort_values(ascending=False)
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# dtype: int64

# %%
df2
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
A = df2.groupby(["Description"])[["Quantity"]].max().head(20)

# %%
A = A.reset_index()

# %%
a = A.sort_values(by='Quantity', ascending=False)

# %%
a
# Out:
#                          Description  Quantity
# 8    SET 2 TEA TOWELS I LOVE LONDON        600
# 2                  DOLLY GIRL BEAKER       400
# 7            RED SPOT GIFT BAG LARGE       400
# 1      50'S CHRISTMAS GIFT BAG LARGE       400
# 14            10 COLOUR SPACEBOY PEN       288
# 15        12 COLOURED PARTY BALLOONS       100
# 3        I LOVE LONDON MINI BACKPACK        50
# 11                 TRELLIS COAT RACK        48
# 19  12 IVORY ROSE PEG PLACE SETTINGS        36
# 9             SPACEBOY BABY GIFT SET        36
# 16         12 DAISY PEGS IN WOOD BOX        24
# 6         OVAL WALL MIRROR DIAMANTE         24
# 0      4 PURPLE FLOCK DINNER CANDLES        12
# 18      12 HANGING EGGS HAND PAINTED        10
# 17         12 EGG HOUSE PAINTED WOOD         8
# 5            NINE DRAWER OFFICE TIDY         6
# 10          TOADSTOOL BEDSIDE LIGHT          2
# 13           *USB Office Mirror Ball         1
# 12             *Boombox Ipod Classic         1
# ...

# %%
plt.figure(figsize=(10,8))
sns.displot(a["Quantity"], kde=False, bins=8);

# %%
plt.figure(figsize=(10,10))
sns.barplot(x="Quantity", y="Description", data=a);

# %%
b = df2.groupby(["Description","Country"])[["Quantity"]].count().head(10)

# %%
b
# Out:
#                                                Quantity
# Description                    Country
#  4 PURPLE FLOCK DINNER CANDLES EIRE                   1
#                                United Kingdom        40
#  50'S CHRISTMAS GIFT BAG LARGE EIRE                   1
#                                France                 1
#                                Germany                5
#                                Portugal               3
#                                Spain                  1
#                                United Kingdom       119
#  DOLLY GIRL BEAKER             Australia              1
#                                Austria                1

# %%
plt.figure(figsize=(10,8))
sns.displot(b["Quantity"], kde=False, bins=8);

# %%
plt.figure(figsize=(10,8))
avrg = df2.groupby(by=["Country"]).mean()
avrg
# Out:
#                        Quantity   UnitPrice    CustomerID
# Country
# Australia             66.444003    3.220612  12464.656076
# Austria               12.037406    4.243192  12521.451372
# Bahrain               13.684211    4.556316  11054.157895
# Belgium               11.189947    3.644335  12430.298695
# Brazil                11.125000    4.456250  12769.000000
# Canada                18.298013    6.030331  17321.079470
# Channel Islands       12.505277    4.932124  14888.151715
# Cyprus                10.155949    6.302363  12404.951768
# Czech Republic        19.733333    2.938333  12781.000000
# Denmark               21.048843    3.256941  12536.591260
# EIRE                  17.403245    5.911077  13469.064910
# European Community     8.147541    4.820492  15108.000000
# Finland               15.346763    5.448705  12517.012950
# France                12.911067    5.028864  12580.218535
# Germany               12.369458    3.966930  12646.139336
# ...

# %%
B = df2.groupby(["Country"])[["Quantity"]].max().head(20)

# %%
B = B.reset_index()

# %%
b = B.sort_values(by='Quantity', ascending=False)

# %%
b
# Out:
#                Country  Quantity
# 10                EIRE      1440
# 0            Australia      1152
# 13              France       912
# 14             Germany       600
# 5               Canada       504
# 6      Channel Islands       407
# 7               Cyprus       288
# 1              Austria       288
# 3              Belgium       272
# 9              Denmark       256
# 17             Iceland       240
# 19               Italy       200
# 16           Hong Kong       144
# 12             Finland       144
# 18              Israel       100
# 2              Bahrain        96
# 8       Czech Republic        72
# 15              Greece        48
# 4               Brazil        24
# 11  European Community        24

# %%
plt.figure(figsize=(10,10))
sns.barplot(x="Quantity", y="Country", data=b);

# %%
c = df2.groupby(["Description"])[["UnitPrice"]].count().head(5)

# %%
c = c.reset_index()

# %%
C = c.sort_values(by="UnitPrice", ascending=False)

# %%
C = c.sort_values(by="UnitPrice", ascending=False)
plt.figure(figsize=(10,10))
plt.title("Fiyat Bazında Satış Adedi", size=20)
plt.xlabel("Fiyat", size=20)
plt.ylabel("Adet",size=20)
plt.plot(c[["UnitPrice"]]);
